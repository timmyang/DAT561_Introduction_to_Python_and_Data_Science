# %% [markdown]
# if condition:
# 	Statement
# 	Statement

# %%
x = int(input("Please enter an integer: "))

if x < 0:
    print('Negative')
if x == 0:
    print('Zero')
if x > 0:
    print('Positive')
# Out:
# Please enter an integer: -2
# Negative

# %% [markdown]
# if-elif-else statement: special version of a decision structure
#
# Makes logic of nested decision structures simpler to write
# Can include multiple elif statements
#
# Syntax: 	if condition1
# 				statements
# 			elif condition2
# 				statements
# 			elif condition3
#                 statements
#
#
#        ----------------
# 			else
# 				statements

# %%
x = int(input('Enter 1st number: '))
y = int(input('Enter 2nd number: '))
if x == y:
	print ('the numbers are equal')
elif x > y:
	print ('the first number is bigger')
else:
	print ('the second number is bigger')

# %%
x = int(input("Enter a number: "))
if x % 2 == 0:
	if x % 3 == 0:
		print ('Divisible by both 2 and 3')
	else:
		print ('Divisible by 2, but not by 3')
elif x % 3 == 0:
	print ('Divisible by 3 and not by 2')
else:
	print ('Divisible by neither 2 nor 3')
# Out:
# Enter a number: 12
# Divisible by both 2 and 3

# %% [markdown]
# while loop: while condition is true, do something
# Two parts:
# Condition tested for true or false value
# Statements repeated as long as condition is true
# In flow chart, line goes back to previous part
# General format:
#
# while condition:
# 	statements

# %%
# squaring an integer, the hard way
x = 4
ans = 0
iters_left = x
while iters_left != 0:
    ans = ans + x
    iters_left = iters_left - 1
    
ans
# Out:
# 16

# %% [markdown]
# Dual alternative decision structure: two possible paths of execution
# One is taken if the condition is true, and the other if the condition is false
# Syntax:
# if condition:
# 	statements
# else:
# 	other statements
#
# if clause and else clause must be aligned.
# Statements must be consistently indented.

# %% [markdown]
# # This is a guess the number game.

# %%
import random

guessesTaken = 0
print('Hello! What is your name?')
myName = input()

number = random.randint(1, 50)
print('Well', myName , 'I am thinking of a number between 1 and 50.')
print(f'Hi, {myName} You have a maximum of 6 quesses to get the right number.')

while guessesTaken < 6:
    print('Take a guess.') # There are four spaces in front of print.
    guess = input()
    guess = int(guess)

    guessesTaken = guessesTaken + 1

    if guess < number:
       print('Your guess is too low.') # There are eight spaces in front of print.

    if guess > number:
       print('Your guess is too high.')

    if guess == number:
       break

#end of while statement

if guess == number:
    print(f'Good job, {myName}! You guessed my number in {guessesTaken} guesses!')

if guess != number:
    print(f'Nope. The number I was thinking of was {number}')
# Out:
# Hello! What is your name?
# Gary
# Well Gary I am thinking of a number between 1 and 50.
# Hi, Gary You have a maximum of 6 quesses to get the right number.
# Take a guess.
# 25
# Your guess is too high.
# Take a guess.
# 13
# Your guess is too low.
# Take a guess.
# 20
# Your guess is too low.
# Take a guess.
# 23
# Good job, Gary! You guessed my number in 4 guesses!

# %% [markdown]
# ![nested%20decision%20tree.png]

# %% [markdown]
# ![nested%20decision%20tree.png](attachment:nested%20decision%20tree.png)

# %%
import random
n = 10
#L = [random.randrange(1, 50) for i in range(n)] #will not include 50
L = [random.randint(1,50) for in in range(n)] #inclusive
print(L)
# Out:
# [26, 22, 28, 1, 35, 22, 18, 25, 26, 41]

# %%
# %pwd
# Out:
# 'C:\\Users\\linga'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\linga'
